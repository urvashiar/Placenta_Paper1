# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import os,shutil
import pandas as pd
import keras
from keras.layers import *
from keras import models
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import load_img
from keras.models import load_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import autokeras as ak
from autokeras import StructuredDataClassifier
import numpy as np

def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# %%
path="/home/urvashiarora3195/Capstone_project/Paper1_revision/data/Third"
train=os.listdir(path)
print(train)
print("Training Data:- ")
for f in train:
    path= "/home/urvashiarora3195/Capstone_project/Paper1_revision/data/Third/" +f
    print(f+ " "+ str(len(os.listdir(path))))
# Out:
# ['Control', 'Case']
# Training Data:-
# Control 481
# Case 341

# %%
# !cd ../data/First/
# !ls ../data/First/
# Out:
# Case  Control

# %%
ls
# Out:
# First_classification.ipynb   Third_classification.ipynb
# Second_classification.ipynb

# %%
from keras.utils import load_img, img_to_array
path="/home/urvashiarora3195/Capstone_project/Paper1_revision/data/Third"
train=os.listdir(path)
print(train)
image_data_train=[]
label_train=[]
for f in train:
    path="/home/urvashiarora3195/Capstone_project/Paper1_revision/data/Third/"+f+'/'
    entries=os.listdir(path)
    for entry in entries:
        if f=='Case':
            label=0
        else:
            label=1
        image=load_img(path+entry,target_size=(224,224,1))
        image_array=np.reshape(np.average((img_to_array(image)/255.0), axis=2), (224,224,1))
        image_data_train.append(image_array)
        label_train.append(label)

image_data_train=np.array(image_data_train)
label_train=np.array(label_train)

print(image_data_train.shape)
# Out:
# ['Control', 'Case']
# (822, 224, 224, 1)

# %%
x_train, X_test, y1_train, y_test = train_test_split(image_data_train, label_train, test_size=0.15, random_state=3)
print(x_train.shape, X_test.shape, y1_train.shape, y_test.shape)
# Out:
# (698, 224, 224, 1) (124, 224, 224, 1) (698,) (124,)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(x_train, y1_train, test_size=0.176, random_state=3)
print(X_train.shape, X_valid.shape, y_train.shape, y_valid.shape)
# Out:
# (575, 224, 224, 1) (123, 224, 224, 1) (575,) (123,)

# %%
pd.Series(y_train).value_counts()
# Out:
# 1    331
# 0    244
# dtype: int64

# %%
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    validation_split=0.2)

# %%
train_data = datagen.fit(X_train)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import layers
from keras.layers import InputLayer
from tensorflow.keras import regularizers
from sklearn.utils import class_weight
#class_weight = {0: 5.6,1: 0.75}

#model = Sequential()

# %%
# model = tf.keras.Sequential([
#     tf.keras.layers.InputLayer(input_shape=(224,224,1), dtype = "float32"),
#   tf.keras.layers.Conv2D(32, kernel_size=(2,2), strides=(1, 1), activation="ReLU"),
#   tf.keras.layers.BatchNormalization(),

#Back up

# model = tf.keras.Sequential([
#   tf.keras.layers.InputLayer(input_shape=(224,224,1), dtype = "float32"),
#   tf.keras.layers.Normalization(axis=-1, mean=None, variance=None),
#   tf.keras.layers.Conv2D(32, kernel_size=(2,2), strides=(1, 1), activation="ReLU"),
#   tf.keras.layers.Conv2D(64, kernel_size=(2,2), strides=(1, 1), activation="ReLU"),
#   tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=None, padding='valid'),
#   tf.keras.layers.Dropout(0.2),
#   tf.keras.layers.Flatten(),
#   tf.keras.layers.Dropout(0.2),
#   tf.keras.layers.Dense(1,activation="sigmoid")])



model = tf.keras.Sequential([
  tf.keras.layers.InputLayer(input_shape=(224,224,1), dtype = "float32"),
  tf.keras.layers.Normalization(axis=-1, mean=None, variance=None),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Conv2D(100, kernel_size=(2,2),strides=(1, 1), activation="ReLU"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Conv2D(85, kernel_size=(2,2), strides=(1, 1), activation="ReLU"),
  tf.keras.layers.MaxPool2D(pool_size=(2, 2), padding='valid'),
  tf.keras.layers.Conv2D(55, kernel_size=(2,2),strides=(1, 1),activation="ReLU"),
  tf.keras.layers.MaxPool2D(pool_size=(2, 2), padding='valid'),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(80,activation='relu'),
  tf.keras.layers.Dropout(0.7),
  tf.keras.layers.Dense(1,activation="sigmoid")])
# Out:
# 2023-06-20 14:25:28.012507: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-06-20 14:25:28.012617: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-06-20 14:25:28.014049: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.00099), loss = 'binary_crossentropy',metrics = ['acc'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 224, 224, 1)      3
#  n)
#
#  dropout (Dropout)           (None, 224, 224, 1)       0
#
#  conv2d (Conv2D)             (None, 223, 223, 100)     500
#
#  batch_normalization (BatchN  (None, 223, 223, 100)    400
#  ormalization)
#
#  dropout_1 (Dropout)         (None, 223, 223, 100)     0
#
#  conv2d_1 (Conv2D)           (None, 222, 222, 85)      34085
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 85)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 110, 110, 55)      18755
#
#  max_pooling2d_1 (MaxPooling  (None, 55, 55, 55)       0
#  2D)
#
#  flatten (Flatten)           (None, 166375)            0
#
#  dense (Dense)               (None, 80)                13310080
#
#  dropout_2 (Dropout)         (None, 80)                0
#
#  dense_1 (Dense)             (None, 1)                 81
#
# =================================================================
# Total params: 13,363,904
# Trainable params: 13,363,701
# Non-trainable params: 203
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train, steps_per_epoch = 3, epochs=70,  validation_data =(X_valid, y_valid))
# Out:
# Epoch 1/70
# 3/3 [==============================] - 62s 21s/step - loss: 51.6573 - acc: 0.5287 - val_loss: 0.8876 - val_acc: 0.4146
# Epoch 2/70
# 3/3 [==============================] - 60s 21s/step - loss: 16.3559 - acc: 0.4609 - val_loss: 0.6973 - val_acc: 0.4146
# Epoch 3/70
# 3/3 [==============================] - 61s 20s/step - loss: 1.6371 - acc: 0.5061 - val_loss: 0.6945 - val_acc: 0.4146
# Epoch 4/70
# 3/3 [==============================] - 59s 20s/step - loss: 0.7728 - acc: 0.5374 - val_loss: 0.6935 - val_acc: 0.4309
# Epoch 5/70
# 3/3 [==============================] - 60s 20s/step - loss: 0.7157 - acc: 0.5565 - val_loss: 0.6927 - val_acc: 0.5854
# Epoch 6/70
# 3/3 [==============================] - 59s 20s/step - loss: 0.6917 - acc: 0.5548 - val_loss: 0.6927 - val_acc: 0.5854
# Epoch 7/70
# 3/3 [==============================] - 60s 20s/step - loss: 0.6913 - acc: 0.5565 - val_loss: 0.6926 - val_acc: 0.5854
# Epoch 8/70
# 3/3 [==============================] - 58s 20s/step - loss: 0.6882 - acc: 0.5757 - val_loss: 0.6925 - val_acc: 0.5854
# Epoch 9/70
# 3/3 [==============================] - 58s 20s/step - loss: 0.6875 - acc: 0.5739 - val_loss: 0.6924 - val_acc: 0.5854
# Epoch 10/70
# 3/3 [==============================] - 58s 20s/step - loss: 0.6827 - acc: 0.5739 - val_loss: 0.6922 - val_acc: 0.5854
# Epoch 11/70
# 3/3 [==============================] - 58s 20s/step - loss: 0.6840 - acc: 0.5826 - val_loss: 0.6920 - val_acc: 0.5854
# Epoch 12/70
# 3/3 [==============================] - 58s 20s/step - loss: 0.6867 - acc: 0.5843 - val_loss: 0.6919 - val_acc: 0.5854
# Epoch 13/70
# 3/3 [==============================] - 60s 20s/step - loss: 0.6789 - acc: 0.5878 - val_loss: 0.6915 - val_acc: 0.5854
# Epoch 14/70
# 3/3 [==============================] - 57s 19s/step - loss: 0.6719 - acc: 0.5791 - val_loss: 0.6916 - val_acc: 0.5854
# Epoch 15/70
# 3/3 [==============================] - 59s 20s/step - loss: 0.6749 - acc: 0.5983 - val_loss: 0.6915 - val_acc: 0.5854
# Epoch 16/70
# 3/3 [==============================] - 60s 20s/step - loss: 0.6746 - acc: 0.5843 - val_loss: 0.6909 - val_acc: 0.5854
# Epoch 17/70
# 3/3 [==============================] - 62s 21s/step - loss: 0.6768 - acc: 0.5913 - val_loss: 0.6906 - val_acc: 0.5854
# Epoch 18/70
# 3/3 [==============================] - 58s 20s/step - loss: 0.6698 - acc: 0.5913 - val_loss: 0.6907 - val_acc: 0.5854
# Epoch 19/70
# 3/3 [==============================] - 64s 22s/step - loss: 0.6690 - acc: 0.6000 - val_loss: 0.6905 - val_acc: 0.5854
# Epoch 20/70
# 3/3 [==============================] - 66s 23s/step - loss: 0.6651 - acc: 0.5965 - val_loss: 0.6901 - val_acc: 0.5854
# Epoch 21/70
# 3/3 [==============================] - 62s 20s/step - loss: 0.6577 - acc: 0.6070 - val_loss: 0.6896 - val_acc: 0.5854
# Epoch 22/70
# 3/3 [==============================] - 61s 21s/step - loss: 0.6646 - acc: 0.5913 - val_loss: 0.6889 - val_acc: 0.5854
# Epoch 23/70
# 3/3 [==============================] - 67s 23s/step - loss: 0.6507 - acc: 0.5565 - val_loss: 0.6878 - val_acc: 0.5854
# Epoch 24/70
# 3/3 [==============================] - 66s 22s/step - loss: 0.6271 - acc: 0.6104 - val_loss: 0.6860 - val_acc: 0.5854
# Epoch 25/70
# 3/3 [==============================] - 67s 22s/step - loss: 0.6424 - acc: 0.6070 - val_loss: 0.6868 - val_acc: 0.5854
# Epoch 26/70
# 3/3 [==============================] - 64s 22s/step - loss: 0.6246 - acc: 0.6087 - val_loss: 0.6868 - val_acc: 0.5854
# Epoch 27/70
# 3/3 [==============================] - 69s 23s/step - loss: 0.6221 - acc: 0.6157 - val_loss: 0.6863 - val_acc: 0.5854
# Epoch 28/70
# 3/3 [==============================] - 65s 22s/step - loss: 0.6042 - acc: 0.6157 - val_loss: 0.6849 - val_acc: 0.5854
# Epoch 29/70
# 3/3 [==============================] - 65s 22s/step - loss: 0.6001 - acc: 0.5913 - val_loss: 0.6841 - val_acc: 0.5854
# Epoch 30/70
# 3/3 [==============================] - 65s 21s/step - loss: 0.6010 - acc: 0.6104 - val_loss: 0.6841 - val_acc: 0.5935
# Epoch 31/70
# 3/3 [==============================] - 66s 22s/step - loss: 0.5689 - acc: 0.6522 - val_loss: 0.6828 - val_acc: 0.5935
# Epoch 32/70
# 3/3 [==============================] - 63s 22s/step - loss: 0.5778 - acc: 0.6226 - val_loss: 0.6827 - val_acc: 0.5854
# Epoch 33/70
# 3/3 [==============================] - 62s 20s/step - loss: 0.5353 - acc: 0.6817 - val_loss: 0.6823 - val_acc: 0.5854
# Epoch 34/70
# 3/3 [==============================] - 56s 20s/step - loss: 0.5454 - acc: 0.6504 - val_loss: 0.6811 - val_acc: 0.5691
# Epoch 35/70
# 3/3 [==============================] - 70s 24s/step - loss: 0.5306 - acc: 0.6504 - val_loss: 0.6811 - val_acc: 0.5610
# Epoch 36/70
# 3/3 [==============================] - 61s 22s/step - loss: 0.5184 - acc: 0.6713 - val_loss: 0.6809 - val_acc: 0.5772
# Epoch 37/70
# 3/3 [==============================] - 69s 24s/step - loss: 0.4743 - acc: 0.7113 - val_loss: 0.6804 - val_acc: 0.5691
# Epoch 38/70
# 3/3 [==============================] - 68s 23s/step - loss: 0.4663 - acc: 0.7252 - val_loss: 0.6788 - val_acc: 0.5772
# Epoch 39/70
# 3/3 [==============================] - 66s 23s/step - loss: 0.4683 - acc: 0.6800 - val_loss: 0.6793 - val_acc: 0.5772
# Epoch 40/70
# 3/3 [==============================] - 65s 22s/step - loss: 0.4645 - acc: 0.6904 - val_loss: 0.6770 - val_acc: 0.5935
# Epoch 41/70
# 3/3 [==============================] - 66s 22s/step - loss: 0.4443 - acc: 0.7287 - val_loss: 0.6759 - val_acc: 0.5935
# Epoch 42/70
# 3/3 [==============================] - 72s 24s/step - loss: 0.4396 - acc: 0.7200 - val_loss: 0.6764 - val_acc: 0.5935
# Epoch 43/70
# 3/3 [==============================] - 63s 21s/step - loss: 0.4133 - acc: 0.7600 - val_loss: 0.6760 - val_acc: 0.6016
# Epoch 44/70
# 3/3 [==============================] - 60s 20s/step - loss: 0.4110 - acc: 0.7548 - val_loss: 0.6764 - val_acc: 0.5935
# Epoch 45/70
# 3/3 [==============================] - 60s 20s/step - loss: 0.3958 - acc: 0.7600 - val_loss: 0.6748 - val_acc: 0.5854
# Epoch 46/70
# 3/3 [==============================] - 32s 10s/step - loss: 0.3500 - acc: 0.7983 - val_loss: 0.6725 - val_acc: 0.5935
# Epoch 47/70
# 3/3 [==============================] - 29s 10s/step - loss: 0.3724 - acc: 0.7652 - val_loss: 0.6710 - val_acc: 0.6016
# Epoch 48/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.3302 - acc: 0.8070 - val_loss: 0.6710 - val_acc: 0.5854
# Epoch 49/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.3228 - acc: 0.7948 - val_loss: 0.6685 - val_acc: 0.5935
# Epoch 50/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.3151 - acc: 0.7739 - val_loss: 0.6656 - val_acc: 0.6098
# Epoch 51/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.3012 - acc: 0.8522 - val_loss: 0.6651 - val_acc: 0.6179
# Epoch 52/70
# 3/3 [==============================] - 28s 9s/step - loss: 0.3061 - acc: 0.8591 - val_loss: 0.6659 - val_acc: 0.6098
# Epoch 53/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.2805 - acc: 0.8765 - val_loss: 0.6651 - val_acc: 0.5935
# Epoch 54/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.2520 - acc: 0.8852 - val_loss: 0.6632 - val_acc: 0.5935
# Epoch 55/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.2503 - acc: 0.8904 - val_loss: 0.6602 - val_acc: 0.5935
# Epoch 56/70
# 3/3 [==============================] - 28s 9s/step - loss: 0.2447 - acc: 0.8852 - val_loss: 0.6615 - val_acc: 0.6016
# Epoch 57/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.2523 - acc: 0.8870 - val_loss: 0.6631 - val_acc: 0.6016
# Epoch 58/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.2697 - acc: 0.8730 - val_loss: 0.6622 - val_acc: 0.6098
# Epoch 59/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.2393 - acc: 0.9009 - val_loss: 0.6581 - val_acc: 0.6179
# Epoch 60/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.2097 - acc: 0.8974 - val_loss: 0.6565 - val_acc: 0.6341
# Epoch 61/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.2134 - acc: 0.9113 - val_loss: 0.6570 - val_acc: 0.6341
# Epoch 62/70
# 3/3 [==============================] - 28s 9s/step - loss: 0.2123 - acc: 0.9113 - val_loss: 0.6548 - val_acc: 0.6098
# Epoch 63/70
# 3/3 [==============================] - 28s 9s/step - loss: 0.2164 - acc: 0.8939 - val_loss: 0.6532 - val_acc: 0.6179
# Epoch 64/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.2176 - acc: 0.8870 - val_loss: 0.6550 - val_acc: 0.6341
# Epoch 65/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.1873 - acc: 0.9200 - val_loss: 0.6558 - val_acc: 0.6341
# Epoch 66/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.1825 - acc: 0.9374 - val_loss: 0.6554 - val_acc: 0.6504
# Epoch 67/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.1767 - acc: 0.9304 - val_loss: 0.6548 - val_acc: 0.6341
# Epoch 68/70
# 3/3 [==============================] - 28s 9s/step - loss: 0.1756 - acc: 0.9200 - val_loss: 0.6532 - val_acc: 0.6504
# Epoch 69/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.1804 - acc: 0.9200 - val_loss: 0.6512 - val_acc: 0.6504
# Epoch 70/70
# 3/3 [==============================] - 28s 10s/step - loss: 0.1543 - acc: 0.9270 - val_loss: 0.6506 - val_acc: 0.6585

# %%
#plt.style.use("seaborn")
plt.plot(hist.history['loss'],label="training loss",c='red')
plt.plot(hist.history['val_loss'],label="validation loss",c='green')
plt.xlabel("Epochs", fontsize=15)
plt.ylabel("Loss", fontsize=15)
plt.ylim(0,1.2)
plt.legend()
plt.show()

# %%
#plt.style.use("seaborn")
plt.plot(hist.history['acc'],label="training acc",c='red')
plt.plot(hist.history['val_acc'],label="validation acc",c='green')
plt.xlabel("Epochs", fontsize=15)
plt.ylabel("Accuracy", fontsize=15)
plt.legend()
plt.show()

# %%
Y_pred_res = model.predict(X_test)
Y_pred=[]
Y_pred_res=list(Y_pred_res)
for res in Y_pred_res:
  if res>0.5:
    Y_pred.append(1)
  else:
    Y_pred.append(0)
y_pred=np.array(Y_pred)

#Confution Matrix and Classification Report
from sklearn.metrics import accuracy_score,f1_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import cohen_kappa_score

print("confusion Matrix:")
print(confusion_matrix(y_test, y_pred)) 
print("**********************************************")
print("Classification Report:")
print(classification_report(y_test, y_pred,target_names=['Case','Control'])) 
print("**********************************************")
print("Accuracy Score :",accuracy_score(y_test, y_pred))
print("**********************************************")
print("F1 Score :",f1_score(y_test, y_pred))
print("**********************************************")
print("Class Wise Accuracy :")
cm=confusion_matrix(y_test, y_pred)
cm=cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
class_wise_acc=cm.diagonal()
print("Case :", class_wise_acc[0]*100)
print("Control :", class_wise_acc[1]*100)
print("**********************************************")
r_score=roc_auc_score(y_test, y_pred, average=None)
print("ROC_AUC Score:",r_score)
print("**********************************************")
RocCurveDisplay.from_predictions(y_test, y_pred)
cohen_score = cohen_kappa_score(y_test, y_pred)
print("Cohen_kappa score:",cohen_score)
# Out:
# 4/4 [==============================] - 1s 254ms/step
# confusion Matrix:
# [[21 25]
#  [14 64]]
# **********************************************
# Classification Report:
#               precision    recall  f1-score   support
#
#         Case       0.60      0.46      0.52        46
#      Control       0.72      0.82      0.77        78
#
#     accuracy                           0.69       124
#    macro avg       0.66      0.64      0.64       124
# weighted avg       0.67      0.69      0.67       124
#
# **********************************************
# Accuracy Score : 0.6854838709677419
# **********************************************
# F1 Score : 0.7664670658682635
# **********************************************
# Class Wise Accuracy :
# Case : 45.65217391304348
# Control : 82.05128205128204
# **********************************************
# ROC_AUC Score: 0.6385172798216276
# **********************************************
# Cohen_kappa score: 0.2913247362250879

# %% [raw]
# Transfer Learning

# %%
from keras.utils import load_img, img_to_array
path="/home/urvashiarora3195/Capstone_project/Paper1_revision/data/Third"
train=os.listdir(path)
print(train)
image_data_train=[]
label_train=[]
for f in train:
    path="/home/urvashiarora3195/Capstone_project/Paper1_revision/data/Third/"+f+'/'
    entries=os.listdir(path)
    for entry in entries:
        if f=='Case':
            label=0
        else:
            label=1
        image=load_img(path+entry,target_size=(224,224,3))
        image_array=img_to_array(image)/255.0
        image_data_train.append(image_array)
        label_train.append(label)

image_data_train=np.array(image_data_train)
label_train=np.array(label_train)

print(image_data_train.shape)
print(len(label_train))
# Out:
# ['Control', 'Case']
# (822, 224, 224, 3)
# 822

# %%
import sklearn.model_selection as sk

x_train, X_test, y1_train, y_test =  sk.train_test_split(image_data_train,label_train,test_size=0.15, random_state = 42, stratify = label_train)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(x_train, y1_train, test_size=0.176, random_state=3)
print(X_train.shape, X_valid.shape, y_train.shape, y_valid.shape)
# Out:
# (575, 224, 224, 3) (123, 224, 224, 3) (575,) (123,)

# %%
# !pip install -U efficientnet

import efficientnet.keras as efn

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras import layers
from tensorflow.keras import Model

base_model = efn.EfficientNetB0(input_shape=(224, 224,3), include_top=False, weights="imagenet")

for layer in base_model.layers:
    layer.trainable = False
# Out:
# Requirement already satisfied: efficientnet in /home/urvashiarora3195/miniconda3/lib/python3.9/site-packages (1.1.1)
# Requirement already satisfied: scikit-image in /home/urvashiarora3195/miniconda3/lib/python3.9/site-packages (from efficientnet) (0.19.3)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /home/urvashiarora3195/miniconda3/lib/python3.9/site-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /home/urvashiarora3195/miniconda3/lib/python3.9/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.24.0)
# Requirement already satisfied: h5py in /home/urvashiarora3195/miniconda3/lib/python3.9/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.7.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/urvashiarora3195/miniconda3/lib/python3.9/site-packages (from scikit-image->efficientnet) (2023.1.23.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/urvashiarora3195/miniconda3/lib/python3.9/site-packages (from scikit-image->efficientnet) (1.4.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /home/urvashiarora3195/miniconda3/lib/python3.9/site-packages (from scikit-image->efficientnet) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in /home/urvashiarora3195/miniconda3/lib/python3.9/site-packages (from scikit-image->efficientnet) (22.0)
# Requirement already satisfied: scipy>=1.4.1 in /home/urvashiarora3195/miniconda3/lib/python3.9/site-packages (from scikit-image->efficientnet) (1.10.0)
# Requirement already satisfied: networkx>=2.2 in /home/urvashiarora3195/miniconda3/lib/python3.9/site-packages (from scikit-image->efficientnet) (3.0)
# Requirement already satisfied: imageio>=2.4.1 in /home/urvashiarora3195/miniconda3/lib/python3.9/site-packages (from scikit-image->efficientnet) (2.25.0)

# %%
from tensorflow.keras import optimizers

x = layers.Flatten()(base_model.output)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.6)(x)
x = layers.Dense(32, activation='relu')(x)

x = layers.Dense(1,activation='sigmoid')(x)

#class_weight = {0: 1.9, 1: 0.7}
model = tf.keras.models.Model(base_model.input, x)
model.compile(optimizer = optimizers.RMSprop(learning_rate=0.0001), loss = 'binary_crossentropy',metrics = ['acc'])

EnetB0hist = model.fit(X_train,y_train, validation_data = (X_valid,y_valid), steps_per_epoch = 3, epochs = 50)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 10s 2s/step - loss: 1.2727 - acc: 0.5304 - val_loss: 1.2867 - val_acc: 0.5691
# Epoch 2/50
# 3/3 [==============================] - 6s 2s/step - loss: 1.0511 - acc: 0.6139 - val_loss: 0.5795 - val_acc: 0.7561
# Epoch 3/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.8218 - acc: 0.5826 - val_loss: 0.4992 - val_acc: 0.6667
# Epoch 4/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.6244 - acc: 0.6870 - val_loss: 0.4726 - val_acc: 0.7480
# Epoch 5/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.5967 - acc: 0.7148 - val_loss: 0.4434 - val_acc: 0.7561
# Epoch 6/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.5832 - acc: 0.7565 - val_loss: 0.4437 - val_acc: 0.7154
# Epoch 7/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.5270 - acc: 0.7443 - val_loss: 0.3793 - val_acc: 0.8049
# Epoch 8/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.5486 - acc: 0.7339 - val_loss: 0.4530 - val_acc: 0.7398
# Epoch 9/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.4561 - acc: 0.7826 - val_loss: 0.3443 - val_acc: 0.8293
# Epoch 10/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.4441 - acc: 0.7983 - val_loss: 0.4428 - val_acc: 0.7480
# Epoch 11/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.3658 - acc: 0.8452 - val_loss: 0.3867 - val_acc: 0.8049
# Epoch 12/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.3390 - acc: 0.8522 - val_loss: 0.4723 - val_acc: 0.7561
# Epoch 13/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.3362 - acc: 0.8487 - val_loss: 0.3541 - val_acc: 0.8374
# Epoch 14/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.3791 - acc: 0.8296 - val_loss: 0.3822 - val_acc: 0.8049
# Epoch 15/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.3006 - acc: 0.8661 - val_loss: 0.3537 - val_acc: 0.8130
# Epoch 16/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.2965 - acc: 0.8696 - val_loss: 0.3395 - val_acc: 0.8130
# Epoch 17/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.2597 - acc: 0.8800 - val_loss: 0.3725 - val_acc: 0.8293
# Epoch 18/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.2600 - acc: 0.8870 - val_loss: 0.3678 - val_acc: 0.8374
# Epoch 19/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1970 - acc: 0.9130 - val_loss: 0.3668 - val_acc: 0.8374
# Epoch 20/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.2632 - acc: 0.8904 - val_loss: 0.5577 - val_acc: 0.7398
# Epoch 21/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.2578 - acc: 0.8817 - val_loss: 0.3583 - val_acc: 0.8211
# Epoch 22/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.2519 - acc: 0.8887 - val_loss: 0.6037 - val_acc: 0.7154
# Epoch 23/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.2552 - acc: 0.8800 - val_loss: 0.3434 - val_acc: 0.8455
# Epoch 24/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.2349 - acc: 0.8939 - val_loss: 0.4083 - val_acc: 0.7967
# Epoch 25/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1948 - acc: 0.9096 - val_loss: 0.3522 - val_acc: 0.8374
# Epoch 26/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.2022 - acc: 0.9113 - val_loss: 0.3809 - val_acc: 0.8049
# Epoch 27/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1991 - acc: 0.9235 - val_loss: 0.3545 - val_acc: 0.8455
# Epoch 28/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1838 - acc: 0.9339 - val_loss: 0.3442 - val_acc: 0.8455
# Epoch 29/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1881 - acc: 0.9217 - val_loss: 0.3982 - val_acc: 0.8049
# Epoch 30/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1763 - acc: 0.9252 - val_loss: 0.4962 - val_acc: 0.8293
# Epoch 31/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.2511 - acc: 0.8904 - val_loss: 0.5513 - val_acc: 0.7724
# Epoch 32/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1717 - acc: 0.9217 - val_loss: 0.3842 - val_acc: 0.8374
# Epoch 33/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1233 - acc: 0.9565 - val_loss: 0.4967 - val_acc: 0.7805
# Epoch 34/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1501 - acc: 0.9374 - val_loss: 0.4232 - val_acc: 0.8049
# Epoch 35/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1325 - acc: 0.9443 - val_loss: 0.4132 - val_acc: 0.8293
# Epoch 36/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1104 - acc: 0.9530 - val_loss: 0.4663 - val_acc: 0.7805
# Epoch 37/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.1474 - acc: 0.9426 - val_loss: 0.4839 - val_acc: 0.8130
# Epoch 38/50
# 3/3 [==============================] - 7s 2s/step - loss: 0.1345 - acc: 0.9461 - val_loss: 0.4134 - val_acc: 0.8049
# Epoch 39/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1223 - acc: 0.9513 - val_loss: 0.4072 - val_acc: 0.8211
# Epoch 40/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1194 - acc: 0.9496 - val_loss: 0.5630 - val_acc: 0.7805
# Epoch 41/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.1600 - acc: 0.9287 - val_loss: 0.4127 - val_acc: 0.8455
# Epoch 42/50
# 3/3 [==============================] - 10s 4s/step - loss: 0.1246 - acc: 0.9530 - val_loss: 0.3925 - val_acc: 0.8293
# Epoch 43/50
# 3/3 [==============================] - 9s 3s/step - loss: 0.1103 - acc: 0.9548 - val_loss: 0.3865 - val_acc: 0.8293
# Epoch 44/50
# 3/3 [==============================] - 9s 3s/step - loss: 0.0819 - acc: 0.9704 - val_loss: 0.5053 - val_acc: 0.7805
# Epoch 45/50
# 3/3 [==============================] - 9s 3s/step - loss: 0.1046 - acc: 0.9704 - val_loss: 0.3985 - val_acc: 0.8211
# Epoch 46/50
# 3/3 [==============================] - 9s 3s/step - loss: 0.1092 - acc: 0.9530 - val_loss: 0.4394 - val_acc: 0.7967
# Epoch 47/50
# 3/3 [==============================] - 9s 3s/step - loss: 0.0716 - acc: 0.9739 - val_loss: 0.4465 - val_acc: 0.7967
# Epoch 48/50
# 3/3 [==============================] - 9s 3s/step - loss: 0.0777 - acc: 0.9739 - val_loss: 0.4374 - val_acc: 0.8293
# Epoch 49/50
# 3/3 [==============================] - 9s 3s/step - loss: 0.0765 - acc: 0.9670 - val_loss: 0.5353 - val_acc: 0.7967
# Epoch 50/50
# 3/3 [==============================] - 9s 3s/step - loss: 0.0786 - acc: 0.9704 - val_loss: 0.4590 - val_acc: 0.8130

# %%
plt.style.use("seaborn")
plt.plot(moving_average(EnetB0hist.history['loss'], 2), color ="red", label = 'Training Loss')
plt.plot(moving_average(EnetB0hist.history['val_loss'],2),label="Validation Loss",c='green')

y1 = EnetB0hist.history["acc"]
y2 = EnetB0hist.history["val_acc"]
# plt.style.use("commetedseaborn")

plt.xlabel("Epochs", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_1585682/2763592790.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
plt.style.use("seaborn")
plt.plot(moving_average(EnetB0hist.history['acc'], 2), color ="red", label = 'Training Accuracy')
plt.plot(moving_average(EnetB0hist.history['val_acc'],2),label="Validation Accuracy",c='green')

y1 = EnetB0hist.history["acc"]
y2 = EnetB0hist.history["val_acc"]
# plt.style.use("commetedseaborn")

plt.xlabel("Epochs", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_1585682/261769242.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
Y_pred_res = model.predict(X_test)
Y_pred=[]
Y_pred_res=list(Y_pred_res)
for res in Y_pred_res:
    if res>0.5:
        Y_pred.append(1)
    else:
        Y_pred.append(0)
y_pred=np.array(Y_pred)

#Confution Matrix and Classification Report
from sklearn.metrics import accuracy_score,f1_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import cohen_kappa_score

print("confusion Matrix:")
print(confusion_matrix(y_test, y_pred)) 
print("**********************************************")
print("Classification Report:")
print(classification_report(y_test, y_pred,target_names=['Case','Control'])) 
print("**********************************************")
print("Accuracy Score :",accuracy_score(y_test, y_pred))
print("**********************************************")
print("F1 Score :",f1_score(y_test, y_pred))
print("**********************************************")
print("Class Wise Accuracy :")
cm=confusion_matrix(y_test, y_pred)
cm=cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
class_wise_acc=cm.diagonal()
print("Case :", class_wise_acc[0]*100)
print("Control :", class_wise_acc[1]*100)
print("**********************************************")
r_score=roc_auc_score(y_test, y_pred, average=None)
print("ROC_AUC Score:",r_score)
print("**********************************************")
RocCurveDisplay.from_predictions(y_test, y_pred)
cohen_score = cohen_kappa_score(y_test, y_pred)
print("Cohen_kappa score:",cohen_score)
# Out:
# 4/4 [==============================] - 3s 357ms/step
# confusion Matrix:
# [[47  4]
#  [11 62]]
# **********************************************
# Classification Report:
#               precision    recall  f1-score   support
#
#         Case       0.81      0.92      0.86        51
#      Control       0.94      0.85      0.89        73
#
#     accuracy                           0.88       124
#    macro avg       0.87      0.89      0.88       124
# weighted avg       0.89      0.88      0.88       124
#
# **********************************************
# Accuracy Score : 0.8790322580645161
# **********************************************
# F1 Score : 0.8920863309352518
# **********************************************
# Class Wise Accuracy :
# Case : 92.15686274509804
# Control : 84.93150684931507
# **********************************************
# ROC_AUC Score: 0.8854418479720655
# **********************************************
# Cohen_kappa score: 0.7552631578947369
